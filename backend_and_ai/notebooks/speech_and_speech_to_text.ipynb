# %%
import random

# %%
from gtts import gTTS
from IPython.display import Audio
import IPython.display as ipd

# %%
import speech_recognition as sr

# %%
def speech_to_text():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("Please speak now...")
        audio = r.listen(source)
    try:
        text = r.recognize_google(audio)
        print("You said: " + text)
        return text
    except sr.UnknownValueError:
        print("Google Speech Recognition could not understand audio")
        return ""
    except sr.RequestError as e:
        print("Could not request results from Google Speech Recognition service; {0}".format(e))
        return ""

# %%
def text_to_speech_response(response_text):
    tts = gTTS(response_text)
    audio_file = 'response.wav'
    tts.save(audio_file)
    return audio_file

# %%
import requests
import json

# %%
speech_text=speech_to_text()
speech_text
# Out:
# Please speak now...
# You said: can you please find where my card is
# 'can you please find where my card is'

# %%
speech_text="Where is my card?"

# %%
url = "http://0.0.0.0:8000/nlp/chat"

payload = json.dumps({
  "input": speech_text
})
headers = {
  'Content-Type': 'application/json'
}

response = requests.request("POST", url, headers=headers, data=payload)

# %%
res = response.json()["result"]["response"]
res
# Out:
# "Your card should arrive within 7-10 business days. You can track its status in the 'Cards' section of our app. If your card hasn't arrived after 10 days, please contact our customer support directly through the app."

# %%
text_to_speech_response(res)
# Out:
# 'response.wav'

# %%
ipd.display(ipd.Audio('response.wav', autoplay=True))
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
